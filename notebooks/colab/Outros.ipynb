# %% [markdown]
# <a href="https://colab.research.google.com/github/H2IA/escola-de-verao-2021/blob/main/notebooks/colab/Outros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Hub IA - marca 02.png](data:image/png;base64,...)

# %% [markdown]
# #Baixar Códigos do Github

# %% [markdown]
# #Baixar Modelos

# %% [markdown]
# Alguns pacotes Python necessitam de recursos externos. O pacote spaCy, por exemplo, vem apenas com modelos para a língua inglesa. Quando baixamos os modelos para a língua portuguesa eles ficam na VM do colab mas não são reconhecidos pelo ambiente Python que já estava em execução. Por isso, para utilizarmos esses modelos precisamos reiniciar o `runtime python`
#
# ![Captura de Tela 2021-02-20 às 10.53.19.png](data:image/png;base64,...)

# %%
# !pip -qqq install spacy
# !python -m spacy download pt_core_news_sm

# %%
import spacy
from spacy.lang.pt.examples import sentences 

nlp = spacy.load("pt_core_news_sm")
doc = nlp(sentences[0])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
